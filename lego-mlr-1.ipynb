# %% [markdown]
# # Lego Multiple Linear Regression

# %% [markdown]
# ## Obtaining Data

# %% [markdown]
# The data has been provided to us as two database files, lego.db and Walmart.db, and a csv, economy_data.csv. We will pull all the data from these files, combine them where possible, and save the combined datasets to csv.

# %%
import sqlite3
import pandas as pd

# %% [markdown]
# First, we need to get the info on all the tables from the database.

# %%
def print_table_data(database_name):
    con = sqlite3.connect(database_name)
    cur = con.cursor()
    cur.execute("""SELECT name
                   FROM sqlite_master
                   WHERE type='table'
                   ORDER BY name;
                """)
    tables = [t[0] for t in cur.fetchall()]
    for table in tables:
        print(f'Table: {table}\nInfo:')
        cur.execute(f"""SELECT *
                        FROM {table};
                     """)
        df = pd.DataFrame(cur.fetchall())
        df.columns = [c[0] for c in cur.description]
        print(df.info())

# %%
print_table_data('data/lego.db')
# Out:
# Table: product_details
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 4 columns):
# prod_id           744 non-null int64
# prod_desc         744 non-null object
# prod_long_desc    744 non-null object
# theme_name        744 non-null object
# dtypes: int64(1), object(3)
# memory usage: 23.4+ KB
# None
# Table: product_info
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 4 columns):
# prod_id        744 non-null int64
# ages           744 non-null object
# piece_count    744 non-null int64
# set_name       744 non-null object
# dtypes: int64(2), object(2)
# memory usage: 23.4+ KB
# None
# Table: product_pricing
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10870 entries, 0 to 10869
# Data columns (total 3 columns):
# prod_id       10870 non-null int64
# country       10870 non-null object
# list_price    10870 non-null object
# dtypes: int64(1), object(2)
# memory usage: 254.9+ KB
# None
# Table: product_reviews
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 6 columns):
# prod_id              744 non-null int64
# num_reviews          655 non-null float64
# play_star_rating     648 non-null float64
# review_difficulty    744 non-null object
# star_rating          655 non-null float64
# val_star_rating      647 non-null float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 35.0+ KB
# None

# %% [markdown]
# All the tables use the same 'prod_id' value as their key, so combining is an easy join statement. After printing out some of the details of our new table, we save it to a csv so it can be easily read into a pandas dataframe later.

# %%
con = sqlite3.connect('data/lego.db')
cur = con.cursor()
cur.execute("""SELECT *
               FROM product_info
               JOIN product_details
               USING(prod_id)
               JOIN product_pricing
               USING(prod_id)
               JOIN product_reviews
               USING(prod_id);
            """)
lego_df = pd.DataFrame(cur.fetchall())
lego_df.columns = [c[0] for c in cur.description]
lego_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10870 entries, 0 to 10869
# Data columns (total 14 columns):
# prod_id              10870 non-null int64
# ages                 10870 non-null object
# piece_count          10870 non-null int64
# set_name             10870 non-null object
# prod_desc            10870 non-null object
# prod_long_desc       10870 non-null object
# theme_name           10870 non-null object
# country              10870 non-null object
# list_price           10870 non-null object
# num_reviews          9449 non-null float64
# play_star_rating     9321 non-null float64
# review_difficulty    10870 non-null object
# star_rating          9449 non-null float64
# val_star_rating      9301 non-null float64
# dtypes: float64(4), int64(2), object(8)
# memory usage: 1.2+ MB

# %%
lego_df
# Out:
#        prod_id  ages  piece_count                        set_name prod_desc  \
# 0        75823  6-12          277           Bird Island Egg Heist      blah
# 1        75822  6-12          168              Piggy Plane Attack      blah
# 2        75821  6-12           74                Piggy Car Escape      blah
# 3        21030   12+         1032  United States Capitol Building      blah
# 4        21035   12+          744   Solomon R. Guggenheim Museum®      blah
# ...        ...   ...          ...                             ...       ...
# 10865    70903  7-14          254       The Riddler™ Riddle Racer      blah
# 10866    70910  7-14          204     Scarecrow™ Special Delivery      blah
# 10867    70901  7-14          201          Mr. Freeze™ Ice Attack      blah
# 10868    70913  6-12          141     Scarecrow™ Fearful Face-off      blah
# 10869    70900  6-12          124       The Joker™ Balloon Escape      blah
#
#       prod_long_desc              theme_name country list_price  num_reviews  \
# 0           blahblah            Angry Birds™      US      29.99          2.0
# 1           blahblah            Angry Birds™      US      19.99          2.0
# 2           blahblah            Angry Birds™      US      12.99         11.0
# 3           blahblah            Architecture      US      99.99         23.0
# 4           blahblah            Architecture      US      79.99         14.0
# ...              ...                     ...     ...        ...          ...
# 10865       blahblah  THE LEGO® BATMAN MOVIE      PT    42.6878         18.0
# 10866       blahblah  THE LEGO® BATMAN MOVIE      PT    30.4878          8.0
# 10867       blahblah  THE LEGO® BATMAN MOVIE      PT    30.4878         19.0
# 10868       blahblah  THE LEGO® BATMAN MOVIE      PT    18.2878          7.0
# 10869       blahblah  THE LEGO® BATMAN MOVIE      PT    18.2878         18.0
#
#        play_star_rating review_difficulty  star_rating  val_star_rating
# 0                   4.0           Average          4.5              4.0
# 1                   4.0              Easy          5.0              4.0
# 2                   4.3              Easy          4.3              4.1
# 3                   3.6           Average          4.6              4.3
# 4                   3.2       Challenging          4.6              4.1
# ...                 ...               ...          ...              ...
# 10865               4.2              Easy          4.2              4.4
# 10866               4.1           Average          4.4              4.1
# 10867               4.1              Easy          4.6              4.4
# 10868               4.0              Easy          4.1              4.4
# 10869               4.5              Easy          4.7              4.6
#
# [10870 rows x 14 columns]

# %%
lego_df.to_csv('data/lego.csv')

# %% [markdown]
# Next, we do the same thing with the Walmart.db data. Again, the two tables use the same 'Store' value as an id, so they can be easily joined.

# %%
print_table_data('data/Walmart.db')
# Out:
# Table: sales
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452192 entries, 0 to 452191
# Data columns (total 5 columns):
# Store           452192 non-null int64
# Dept            452192 non-null int64
# Date            452192 non-null object
# Weekly_Sales    452192 non-null float64
# IsHoliday       452192 non-null object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 17.2+ MB
# None
# Table: store_details
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 3 columns):
# Store    45 non-null int64
# Type     45 non-null object
# Size     45 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 1.2+ KB
# None

# %%
con = sqlite3.connect('data/Walmart.db')
cur = con.cursor()
cur.execute("""SELECT *
               FROM sales
               JOIN store_details
               USING(Store);
            """)
walmart_df = pd.DataFrame(cur.fetchall())
walmart_df.columns = [c[0] for c in cur.description]
walmart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452192 entries, 0 to 452191
# Data columns (total 7 columns):
# Store           452192 non-null int64
# Dept            452192 non-null int64
# Date            452192 non-null object
# Weekly_Sales    452192 non-null float64
# IsHoliday       452192 non-null object
# Type            452192 non-null object
# Size            452192 non-null int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 24.1+ MB

# %%
walmart_df
# Out:
#         Store  Dept        Date  Weekly_Sales IsHoliday Type    Size
# 0           1     1  2010-02-05      24924.50     False    A  151315
# 1           1     1  2010-02-12      46039.49      True    A  151315
# 2           1     1  2010-02-19      41595.55     False    A  151315
# 3           1     1  2010-02-26      19403.54     False    A  151315
# 4           1     1  2010-03-05      21827.90     False    A  151315
# ...       ...   ...         ...           ...       ...  ...     ...
# 452187     45    98  2012-09-28        508.37     False    B  118221
# 452188     45    98  2012-10-05        628.10     False    B  118221
# 452189     45    98  2012-10-12       1061.02     False    B  118221
# 452190     45    98  2012-10-19        760.01     False    B  118221
# 452191     45    98  2012-10-26       1076.80     False    B  118221
#
# [452192 rows x 7 columns]

# %% [markdown]
# Finally, there is an economy_data.csv file. It has unique 'Store' and 'Date' values, similar to our walmart_df. We can merge the two dataframes and save the result as walmart.csv

# %%
economy_df = pd.read_csv('data/economy_data.csv')
economy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
# Store           8190 non-null int64
# Date            8190 non-null object
# Temperature     8190 non-null float64
# Fuel_Price      8190 non-null float64
# MarkDown1       4032 non-null float64
# MarkDown2       2921 non-null float64
# MarkDown3       3613 non-null float64
# MarkDown4       3464 non-null float64
# MarkDown5       4050 non-null float64
# CPI             7605 non-null float64
# Unemployment    7605 non-null float64
# IsHoliday       8190 non-null bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 712.0+ KB

# %%
economy_df
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  2010-02-05        42.31       2.572        NaN        NaN
# 1         1  2010-02-12        38.51       2.548        NaN        NaN
# 2         1  2010-02-19        39.93       2.514        NaN        NaN
# 3         1  2010-02-26        46.63       2.561        NaN        NaN
# 4         1  2010-03-05        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45  2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0           NaN        NaN        NaN  211.096358         8.106      False
# 1           NaN        NaN        NaN  211.242170         8.106       True
# 2           NaN        NaN        NaN  211.289143         8.106      False
# 3           NaN        NaN        NaN  211.319643         8.106      False
# 4           NaN        NaN        NaN  211.350143         8.106      False
# ...         ...        ...        ...         ...           ...        ...
# 8185       3.00    2449.97    3169.69         NaN           NaN      False
# 8186     582.74    5797.47    1514.93         NaN           NaN      False
# 8187      85.72     744.84    2150.36         NaN           NaN      False
# 8188     204.19     363.00    1059.46         NaN           NaN      False
# 8189       2.06      10.88    1864.57         NaN           NaN      False
#
# [8190 rows x 12 columns]

# %%
walmart_combined_df = pd.merge(walmart_df, economy_df,  how='left', on=['Store','Date'])
walmart_combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 452192 entries, 0 to 452191
# Data columns (total 17 columns):
# Store           452192 non-null int64
# Dept            452192 non-null int64
# Date            452192 non-null object
# Weekly_Sales    452192 non-null float64
# IsHoliday_x     452192 non-null object
# Type            452192 non-null object
# Size            452192 non-null int64
# Temperature     452192 non-null float64
# Fuel_Price      452192 non-null float64
# MarkDown1       161614 non-null float64
# MarkDown2       120077 non-null float64
# MarkDown3       147431 non-null float64
# MarkDown4       145762 non-null float64
# MarkDown5       162365 non-null float64
# CPI             452192 non-null float64
# Unemployment    452192 non-null float64
# IsHoliday_y     452192 non-null bool
# dtypes: bool(1), float64(10), int64(3), object(3)
# memory usage: 59.1+ MB

# %%
walmart_combined_df
# Out:
#         Store  Dept        Date  Weekly_Sales IsHoliday_x Type    Size  \
# 0           1     1  2010-02-05      24924.50       False    A  151315
# 1           1     1  2010-02-12      46039.49        True    A  151315
# 2           1     1  2010-02-19      41595.55       False    A  151315
# 3           1     1  2010-02-26      19403.54       False    A  151315
# 4           1     1  2010-03-05      21827.90       False    A  151315
# ...       ...   ...         ...           ...         ...  ...     ...
# 452187     45    98  2012-09-28        508.37       False    B  118221
# 452188     45    98  2012-10-05        628.10       False    B  118221
# 452189     45    98  2012-10-12       1061.02       False    B  118221
# 452190     45    98  2012-10-19        760.01       False    B  118221
# 452191     45    98  2012-10-26       1076.80       False    B  118221
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# 0             42.31       2.572        NaN        NaN        NaN        NaN
# 1             38.51       2.548        NaN        NaN        NaN        NaN
# 2             39.93       2.514        NaN        NaN        NaN        NaN
# 3             46.63       2.561        NaN        NaN        NaN        NaN
# 4             46.50       2.625        NaN        NaN        NaN        NaN
# ...             ...         ...        ...        ...        ...        ...
# 452187        64.88       3.997    4556.61      20.64       1.50    1601.01
# 452188        64.89       3.985    5046.74        NaN      18.82    2253.43
# 452189        54.47       4.000    1956.28        NaN       7.89     599.32
# 452190        56.47       3.969    2004.02        NaN       3.18     437.73
# 452191        58.85       3.882    4018.91      58.08     100.00     211.94
#
#         MarkDown5         CPI  Unemployment  IsHoliday_y
# 0             NaN  211.096358         8.106        False
# 1             NaN  211.242170         8.106         True
# 2             NaN  211.289143         8.106        False
# 3             NaN  211.319643         8.106        False
# 4             NaN  211.350143         8.106        False
# ...           ...         ...           ...          ...
# 452187    3288.25  192.013558         8.684        False
# 452188    2340.01  192.170412         8.667        False
# 452189    3990.54  192.327265         8.667        False
# 452190    1537.49  192.330854         8.667        False
# 452191     858.33  192.308899         8.667        False
#
# [452192 rows x 17 columns]

# %%
walmart_combined_df.to_csv('data/walmart.csv')

# %% [markdown]
# ## Scrubbing and Cleaning Data

# %% [markdown]
# In order to begin the data cleaning process, we will import the necessary pacakges, and then will load the relevant dataset that was created above, "data/lego.csv", as a DataFrame.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
df = pd.read_csv('data/lego.csv', index_col=0)
df.head()
# Out:
#    prod_id  ages  piece_count                        set_name prod_desc  \
# 0    75823  6-12          277           Bird Island Egg Heist      blah
# 1    75822  6-12          168              Piggy Plane Attack      blah
# 2    75821  6-12           74                Piggy Car Escape      blah
# 3    21030   12+         1032  United States Capitol Building      blah
# 4    21035   12+          744   Solomon R. Guggenheim Museum®      blah
#
#   prod_long_desc    theme_name country  list_price  num_reviews  \
# 0       blahblah  Angry Birds™      US       29.99          2.0
# 1       blahblah  Angry Birds™      US       19.99          2.0
# 2       blahblah  Angry Birds™      US       12.99         11.0
# 3       blahblah  Architecture      US       99.99         23.0
# 4       blahblah  Architecture      US       79.99         14.0
#
#    play_star_rating review_difficulty  star_rating  val_star_rating
# 0               4.0           Average          4.5              4.0
# 1               4.0              Easy          5.0              4.0
# 2               4.3              Easy          4.3              4.1
# 3               3.6           Average          4.6              4.3
# 4               3.2       Challenging          4.6              4.1

# %% [markdown]
# ### Starting our Data Cleaning
#
# The first step will be to check the data types of each column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10870 entries, 0 to 10869
# Data columns (total 14 columns):
# prod_id              10870 non-null int64
# ages                 10870 non-null object
# piece_count          10870 non-null int64
# set_name             10870 non-null object
# prod_desc            10870 non-null object
# prod_long_desc       10870 non-null object
# theme_name           10870 non-null object
# country              10870 non-null object
# list_price           10870 non-null float64
# num_reviews          9449 non-null float64
# play_star_rating     9321 non-null float64
# review_difficulty    9104 non-null object
# star_rating          9449 non-null float64
# val_star_rating      9301 non-null float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 1.2+ MB

# %% [markdown]
# We'll now investigate some of the unique values inside of the `list_price` column.

# %%
df['list_price'].nunique()
# Out:
# 733

# %%
df['list_price'].unique()[:10]
# Out:
# array([ 29.99,  19.99,  12.99,  99.99,  79.99,  59.99,  49.99,  39.99,
#         34.99, 159.99])

# %% [markdown]
# Our next step will be to identify any null values in the dataset and deal with them accordingly.

# %%
df.isna().sum()
# Out:
# prod_id                 0
# ages                    0
# piece_count             0
# set_name                0
# prod_desc               0
# prod_long_desc          0
# theme_name              0
# country                 0
# list_price              0
# num_reviews          1421
# play_star_rating     1549
# review_difficulty    1766
# star_rating          1421
# val_star_rating      1569
# dtype: int64

# %%
df.describe()
# Out:
#             prod_id   piece_count    list_price  num_reviews  \
# count  1.087000e+04  10870.000000  10870.000000  9449.000000
# mean   6.181634e+04    503.936431     67.309137    17.813737
# std    1.736390e+05    831.209318     94.669414    38.166693
# min    6.300000e+02      1.000000      2.272400     1.000000
# 25%    2.112300e+04     97.000000     21.899000     2.000000
# 50%    4.207350e+04    223.000000     36.587800     6.000000
# 75%    7.124800e+04    556.000000     73.187800    14.000000
# max    2.000431e+06   7541.000000   1104.870000   367.000000
#
#        play_star_rating  star_rating  val_star_rating
# count       9321.000000  9449.000000      9301.000000
# mean           4.355413     4.510319         4.214439
# std            0.617272     0.516463         0.670906
# min            1.000000     1.800000         1.000000
# 25%            4.000000     4.300000         4.000000
# 50%            4.500000     4.600000         4.300000
# 75%            4.800000     5.000000         4.700000
# max            5.000000     5.000000         5.000000

# %%
df_new = df.loc[:, ('num_reviews', 'play_star_rating', 'star_rating', 'val_star_rating')]
sns.heatmap(df_new.corr(), center=0, cmap="Blues");

# %% [markdown]
# Here we see that play_star_rating, star_rating, and val_star_rating appear to be highly correlated.

# %%
len(df[(df.play_star_rating.isnull()) & (df.val_star_rating.isnull())& (df.star_rating.isnull())])
# Out:
# 1421

# %%
df['play_star_rating'] = df['play_star_rating'].fillna(df['play_star_rating'].median())

# %%
df['star_rating'] = df['star_rating'].fillna(df['star_rating'].median())

# %%
df['val_star_rating'] = df['val_star_rating'].fillna(df['val_star_rating'].median())

# %%
df['review_difficulty'] = df['review_difficulty'].fillna(value="unknown")

# %% [markdown]
# ### Normalizing the data
#
# Our next step will be to normalize the data by converting values to their corresponding z scores.

# %%
def normalize(value):
    value = np.log(value)
    z = (value - value.min()) / (value.max() - value.min())
    return z

# %%
numeric = ['piece_count', 'num_reviews', 'play_star_rating', 'star_rating', 'val_star_rating']

for col in numeric:
    df[col] = normalize(df[col])

# %%
df.describe()
# Out:
#             prod_id   piece_count    list_price  num_reviews  \
# count  1.087000e+04  10870.000000  10870.000000  9449.000000
# mean   6.181634e+04      0.593099     67.309137     0.317276
# std    1.736390e+05      0.178828     94.669414     0.223133
# min    6.300000e+02      0.000000      2.272400     0.000000
# 25%    2.112300e+04      0.512394     21.899000     0.117376
# 50%    4.207350e+04      0.605635     36.587800     0.303412
# 75%    7.124800e+04      0.707963     73.187800     0.446892
# max    2.000431e+06      1.000000   1104.870000     1.000000
#
#        play_star_rating   star_rating  val_star_rating
# count      10870.000000  10870.000000     10870.000000
# mean           0.910304      0.894979         0.887175
# std            0.099761      0.120300         0.109792
# min            0.000000      0.000000         0.000000
# 25%            0.876695      0.852373         0.861353
# 50%            0.934536      0.918385         0.906288
# 75%            0.961555      0.980225         0.948192
# max            1.000000      1.000000         1.000000

# %%
df.to_csv("Lego_cleaned.csv", index=False)

# %% [markdown]
# ### One-Hot Coding Categorial Columns
#
# We will now convert the categorial variables to dummy variables.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10870 entries, 0 to 10869
# Data columns (total 14 columns):
# prod_id              10870 non-null int64
# ages                 10870 non-null object
# piece_count          10870 non-null float64
# set_name             10870 non-null object
# prod_desc            10870 non-null object
# prod_long_desc       10870 non-null object
# theme_name           10870 non-null object
# country              10870 non-null object
# list_price           10870 non-null float64
# num_reviews          9449 non-null float64
# play_star_rating     10870 non-null float64
# review_difficulty    10870 non-null object
# star_rating          10870 non-null float64
# val_star_rating      10870 non-null float64
# dtypes: float64(6), int64(1), object(7)
# memory usage: 1.2+ MB

# %%
categorial = ['ages', 'theme_name', 'country', 'review_difficulty']
df_new = df[categorial]
df_new = pd.get_dummies(df_new, drop_first=True)

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10870 entries, 0 to 10869
# Data columns (total 93 columns):
# ages_10-14                                          10870 non-null uint8
# ages_10-16                                          10870 non-null uint8
# ages_10-21                                          10870 non-null uint8
# ages_11-16                                          10870 non-null uint8
# ages_12+                                            10870 non-null uint8
# ages_12-16                                          10870 non-null uint8
# ages_14+                                            10870 non-null uint8
# ages_16+                                            10870 non-null uint8
# ages_1½-3                                           10870 non-null uint8
# ages_1½-5                                           10870 non-null uint8
# ages_2-5                                            10870 non-null uint8
# ages_4+                                             10870 non-null uint8
# ages_4-7                                            10870 non-null uint8
# ages_4-99                                           10870 non-null uint8
# ages_5+                                             10870 non-null uint8
# ages_5-12                                           10870 non-null uint8
# ages_5-8                                            10870 non-null uint8
# ages_6+                                             10870 non-null uint8
# ages_6-12                                           10870 non-null uint8
# ages_6-14                                           10870 non-null uint8
# ages_7+                                             10870 non-null uint8
# ages_7-12                                           10870 non-null uint8
# ages_7-14                                           10870 non-null uint8
# ages_8+                                             10870 non-null uint8
# ages_8-12                                           10870 non-null uint8
# ages_8-14                                           10870 non-null uint8
# ages_9+                                             10870 non-null uint8
# ages_9-12                                           10870 non-null uint8
# ages_9-14                                           10870 non-null uint8
# ages_9-16                                           10870 non-null uint8
# theme_name_Architecture                             10870 non-null uint8
# theme_name_BOOST                                    10870 non-null uint8
# theme_name_Blue's Helicopter Pursuit                10870 non-null uint8
# theme_name_BrickHeadz                               10870 non-null uint8
# theme_name_Carnotaurus Gyrosphere Escape            10870 non-null uint8
# theme_name_City                                     10870 non-null uint8
# theme_name_Classic                                  10870 non-null uint8
# theme_name_Creator 3-in-1                           10870 non-null uint8
# theme_name_Creator Expert                           10870 non-null uint8
# theme_name_DC Comics™ Super Heroes                  10870 non-null uint8
# theme_name_DC Super Hero Girls                      10870 non-null uint8
# theme_name_DIMENSIONS™                              10870 non-null uint8
# theme_name_DUPLO®                                   10870 non-null uint8
# theme_name_Dilophosaurus Outpost Attack             10870 non-null uint8
# theme_name_Disney™                                  10870 non-null uint8
# theme_name_Elves                                    10870 non-null uint8
# theme_name_Friends                                  10870 non-null uint8
# theme_name_Ghostbusters™                            10870 non-null uint8
# theme_name_Ideas                                    10870 non-null uint8
# theme_name_Indoraptor Rampage at Lockwood Estate    10870 non-null uint8
# theme_name_Juniors                                  10870 non-null uint8
# theme_name_Jurassic Park Velociraptor Chase         10870 non-null uint8
# theme_name_MINDSTORMS®                              10870 non-null uint8
# theme_name_Marvel Super Heroes                      10870 non-null uint8
# theme_name_Minecraft™                               10870 non-null uint8
# theme_name_Minifigures                              10870 non-null uint8
# theme_name_NEXO KNIGHTS™                            10870 non-null uint8
# theme_name_NINJAGO®                                 10870 non-null uint8
# theme_name_Power Functions                          10870 non-null uint8
# theme_name_Pteranodon Chase                         10870 non-null uint8
# theme_name_SERIOUS PLAY®                            10870 non-null uint8
# theme_name_Speed Champions                          10870 non-null uint8
# theme_name_Star Wars™                               10870 non-null uint8
# theme_name_Stygimoloch Breakout                     10870 non-null uint8
# theme_name_T. rex Transport                         10870 non-null uint8
# theme_name_THE LEGO® BATMAN MOVIE                   10870 non-null uint8
# theme_name_THE LEGO® NINJAGO® MOVIE™                10870 non-null uint8
# theme_name_Technic                                  10870 non-null uint8
# country_AU                                          10870 non-null uint8
# country_BE                                          10870 non-null uint8
# country_CA                                          10870 non-null uint8
# country_CH                                          10870 non-null uint8
# country_CZ                                          10870 non-null uint8
# country_DE                                          10870 non-null uint8
# country_DN                                          10870 non-null uint8
# country_ES                                          10870 non-null uint8
# country_FI                                          10870 non-null uint8
# country_FR                                          10870 non-null uint8
# country_GB                                          10870 non-null uint8
# country_IE                                          10870 non-null uint8
# country_IT                                          10870 non-null uint8
# country_LU                                          10870 non-null uint8
# country_NL                                          10870 non-null uint8
# country_NO                                          10870 non-null uint8
# country_NZ                                          10870 non-null uint8
# country_PL                                          10870 non-null uint8
# country_PT                                          10870 non-null uint8
# country_US                                          10870 non-null uint8
# review_difficulty_Challenging                       10870 non-null uint8
# review_difficulty_Easy                              10870 non-null uint8
# review_difficulty_Very Challenging                  10870 non-null uint8
# review_difficulty_Very Easy                         10870 non-null uint8
# review_difficulty_unknown                           10870 non-null uint8
# dtypes: uint8(93)
# memory usage: 1.0 MB

# %% [markdown]
# ## Exploring Data

# %% [markdown]
# To further explore the data, we need to merge the DataFrame with dummy values in the categorical columns with the DataFrame containig the normalized values in the remaining relevant columns (as well as **list_price**, which is the target variable for our model).

# %%
new_cols = ['piece_count','list_price','num_reviews','play_star_rating','star_rating','val_star_rating']
df = df[new_cols]
df_final = pd.concat([df, df_new], axis=1, join='inner')
df_final.describe()
# Out:
#         piece_count    list_price  num_reviews  play_star_rating  \
# count  10870.000000  10870.000000  9449.000000      10870.000000
# mean       0.593099     67.309137     0.317276          0.910304
# std        0.178828     94.669414     0.223133          0.099761
# min        0.000000      2.272400     0.000000          0.000000
# 25%        0.512394     21.899000     0.117376          0.876695
# 50%        0.605635     36.587800     0.303412          0.934536
# 75%        0.707963     73.187800     0.446892          0.961555
# max        1.000000   1104.870000     1.000000          1.000000
#
#         star_rating  val_star_rating    ages_10-14    ages_10-16  \
# count  10870.000000     10870.000000  10870.000000  10870.000000
# mean       0.894979         0.887175      0.001932      0.013615
# std        0.120300         0.109792      0.043913      0.115894
# min        0.000000         0.000000      0.000000      0.000000
# 25%        0.852373         0.861353      0.000000      0.000000
# 50%        0.918385         0.906288      0.000000      0.000000
# 75%        0.980225         0.948192      0.000000      0.000000
# max        1.000000         1.000000      1.000000      1.000000
#
#          ages_10-21    ages_11-16  ...    country_NO    country_NZ  \
# count  10870.000000  10870.000000  ...  10870.000000  10870.000000
# mean       0.016927      0.006072  ...      0.044802      0.046274
# std        0.129005      0.077688  ...      0.206879      0.210088
# min        0.000000      0.000000  ...      0.000000      0.000000
# 25%        0.000000      0.000000  ...      0.000000      0.000000
# 50%        0.000000      0.000000  ...      0.000000      0.000000
# 75%        0.000000      0.000000  ...      0.000000      0.000000
# max        1.000000      1.000000  ...      1.000000      1.000000
#
#          country_PL    country_PT    country_US  \
# count  10870.000000  10870.000000  10870.000000
# mean       0.043330      0.044618      0.066421
# std        0.203609      0.206474      0.249029
# min        0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000
#
#        review_difficulty_Challenging  review_difficulty_Easy  \
# count                   10870.000000            10870.000000
# mean                        0.091536                0.351978
# std                         0.288384                0.477609
# min                         0.000000                0.000000
# 25%                         0.000000                0.000000
# 50%                         0.000000                0.000000
# 75%                         0.000000                1.000000
# max                         1.000000                1.000000
#
#        review_difficulty_Very Challenging  review_difficulty_Very Easy  \
# count                        10870.000000                 10870.000000
# mean                             0.001932                     0.083257
# std                              0.043913                     0.276282
# min                              0.000000                     0.000000
# 25%                              0.000000                     0.000000
# 50%                              0.000000                     0.000000
# 75%                              0.000000                     0.000000
# max                              1.000000                     1.000000
#
#        review_difficulty_unknown
# count               10870.000000
# mean                    0.162466
# std                     0.368894
# min                     0.000000
# 25%                     0.000000
# 50%                     0.000000
# 75%                     0.000000
# max                     1.000000
#
# [8 rows x 99 columns]

# %% [markdown]
# Next, we'll explore the distributions of the data in each column by plotting historgrams for all the numerical variables in our dataset.

# %%
#To avoid clutter and keep the plots easy for observation, we'll plot the histograms in three groups of 33 
df_final[df_final.columns[:33]].hist(figsize = (24,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7feb6fa85860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb6fab8eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb6f979be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb74988d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb749e0e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb74a79fd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7feb74b67160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb74d872e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb74d87320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb74fc1550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb7509d6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb751387f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7feb746d1940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb747e9a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb6f4ca860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb6f4e72b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb754cc860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb755b2e10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7feb757a2400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb758369b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb758cff60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb759bc550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb75b14b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb752380f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7feb75eb66a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb75f51c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb7603e240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb760d27f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb7616fda0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb7639b390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7feb76574940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb7660cef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb766f94e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb75ba8a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb75d1e080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb76acd630>]],
#       dtype=object)

# %%
df_final[df_final.columns[34:67]].hist(figsize = (24,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7feb76cc6a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb7091b780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb70cad400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb70ccc9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb70d16f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb70d80550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7feb70e11b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb70f31128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb70f31160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb71018c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb71145240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb713207f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7feb714fada0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb71563390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb71698940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb71730ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb717db4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb71830a90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7feb7189f080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb71934630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb71987be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb71baf1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb71d7e780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb71dd7d30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7feb71e43320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb71ff48d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb7204fe80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb720f4470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb7214ea20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb721a4fd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7feb722485c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb722a0b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb7268f160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb726e2710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb727f5cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb728642b0>]],
#       dtype=object)

# %%
df_final[df_final.columns[66:99]].hist(figsize = (24,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7feb74862ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb6f9da7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb74511860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb7485ee10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb748d6400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb74aa89b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7feb74bbff60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb74c2b588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb74c2b5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb74d2b0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb74d836a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb74e12c50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7feb74e80240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb74f107f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb74f69da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb7460b390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb7471d940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb74776ef0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7feb748214e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb7540ca90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb75476080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb75509630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb7555dbe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb756091d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7feb7565d780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb756f2d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb7575f320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb758738d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb7598ae80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb75ab3470>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7feb75b09a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb75152fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb751ba5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb7524fb70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb752bf160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb7534d710>]],
#       dtype=object)

# %% [markdown]
# **Observation:** All columns containing dummy values follow a Bernoulli distribution (as expected) and the remaining predictor columns with normalized values are pretty skewed.

# %% [markdown]
# ### Checking for Linearity
# We'll use joint plots to investigate if there's a linear relationship between the predictor variables and our target variable.

# %%
import warnings
warnings.filterwarnings('ignore')

sns.jointplot(x = 'piece_count', y = 'list_price', data=df_final, kind='reg',height = 9)

# %% [markdown]
# **Observation:** It appears that piece count has a linear relationship with our target list price. The more pieces a lego set has, the higher the price.

# %%
sns.jointplot(x = 'num_reviews', y = 'list_price', data=df_final, kind='reg',height = 9)

# %% [markdown]
# **Observation** There seems to be a much weaker linear relationship between the prices of a lego set and the number of reviews it has received. 95% of the lego sets cost under $220, which explains why most reviewes are skewed in ther lower left lower left quadrant, which adds a lot of noise to the visualiztion of the relationship.

# %%
sns.jointplot(x = 'play_star_rating', y = 'list_price', data=df_final, kind='reg',height = 9)

# %% [markdown]
# **Observation:** List price and play star rating don't have a linear relationship.

# %%
sns.jointplot(x = 'star_rating', y = 'list_price', data=df_final, kind='reg',height = 9)

# %% [markdown]
# **Observation:** List price and star rating also don't have a linear relationship.

# %%
sns.jointplot(x = 'val_star_rating', y = 'list_price', data=df_final, kind='reg',height = 9)

# %% [markdown]
# **Observation:** List price and the val star rating don't have a linear relationship as well.
#
# Conclusion: None of the rating variables have a linear relationship with our target variable, so it's best to exclude them from the model.

# %% [markdown]
# ### Checking for Multicollinearity
# Next, we'll check if the predictive features will result in multicollinearity in our model. We are looking for predictors that have a r<65 pairwise correlation.

# %%
feats = ['piece_count', 'num_reviews', 'play_star_rating','star_rating','val_star_rating']
corr = df_final[feats].corr()
corr
# Out:
#                   piece_count  num_reviews  play_star_rating  star_rating  \
# piece_count          1.000000     0.354806         -0.009953     0.048696
# num_reviews          0.354806     1.000000         -0.073132    -0.130305
# play_star_rating    -0.009953    -0.073132          1.000000     0.594517
# star_rating          0.048696    -0.130305          0.594517     1.000000
# val_star_rating      0.082236    -0.032830          0.449088     0.706829
#
#                   val_star_rating
# piece_count              0.082236
# num_reviews             -0.032830
# play_star_rating         0.449088
# star_rating              0.706829
# val_star_rating          1.000000

# %% [markdown]
# **Observation:** The two predictors that remain (after excluding all ratings due to a lack of linear relationship with the target variable) are **piece count** and **number of reviews**. They have a relatively high correlation (0.54). Perhaps only one of them is worth keeping, e.g. piece count which has a stronger lienar relationsihp with our dependent variable.

# %% [markdown]
# ## Modeling Data

# %% [markdown]
# Re-formatting column names to ensure their don't produce an error when plugged into the formula syntax.

# %%
subs = [(' ', '_'),('.',''),("'",""),('™', ''), ('®',''),
        ('+','plus'), ('½','half'), ('-','_')
       ]
def col_formatting(col):
    for old, new in subs:
        col = col.replace(old,new)
    return col


df_final.columns = [col_formatting(col) for col in df_final.columns]

# %%
df_final.columns
# Out:
# Index(['piece_count', 'list_price', 'num_reviews', 'play_star_rating',
#        'star_rating', 'val_star_rating', 'ages_10_14', 'ages_10_16',
#        'ages_10_21', 'ages_11_16', 'ages_12plus', 'ages_12_16', 'ages_14plus',
#        'ages_16plus', 'ages_1half_3', 'ages_1half_5', 'ages_2_5', 'ages_4plus',
#        'ages_4_7', 'ages_4_99', 'ages_5plus', 'ages_5_12', 'ages_5_8',
#        'ages_6plus', 'ages_6_12', 'ages_6_14', 'ages_7plus', 'ages_7_12',
#        'ages_7_14', 'ages_8plus', 'ages_8_12', 'ages_8_14', 'ages_9plus',
#        'ages_9_12', 'ages_9_14', 'ages_9_16', 'theme_name_Architecture',
#        'theme_name_BOOST', 'theme_name_Blues_Helicopter_Pursuit',
#        'theme_name_BrickHeadz', 'theme_name_Carnotaurus_Gyrosphere_Escape',
#        'theme_name_City', 'theme_name_Classic', 'theme_name_Creator_3_in_1',
#        'theme_name_Creator_Expert', 'theme_name_DC_Comics_Super_Heroes',
#        'theme_name_DC_Super_Hero_Girls', 'theme_name_DIMENSIONS',
#        'theme_name_DUPLO', 'theme_name_Dilophosaurus_Outpost_Attack',
#        'theme_name_Disney', 'theme_name_Elves', 'theme_name_Friends',
#        'theme_name_Ghostbusters', 'theme_name_Ideas',
#        'theme_name_Indoraptor_Rampage_at_Lockwood_Estate',
#        'theme_name_Juniors', 'theme_name_Jurassic_Park_Velociraptor_Chase',
#        'theme_name_MINDSTORMS', 'theme_name_Marvel_Super_Heroes',
#        'theme_name_Minecraft', 'theme_name_Minifigures',
#        'theme_name_NEXO_KNIGHTS', 'theme_name_NINJAGO',
#        'theme_name_Power_Functions', 'theme_name_Pteranodon_Chase',
#        'theme_name_SERIOUS_PLAY', 'theme_name_Speed_Champions',
#        'theme_name_Star_Wars', 'theme_name_Stygimoloch_Breakout',
#        'theme_name_T_rex_Transport', 'theme_name_THE_LEGO_BATMAN_MOVIE',
#        'theme_name_THE_LEGO_NINJAGO_MOVIE', 'theme_name_Technic', 'country_AU',
#        'country_BE', 'country_CA', 'country_CH', 'country_CZ', 'country_DE',
#        'country_DN', 'country_ES', 'country_FI', 'country_FR', 'country_GB',
#        'country_IE', 'country_IT', 'country_LU', 'country_NL', 'country_NO',
#        'country_NZ', 'country_PL', 'country_PT', 'country_US',
#        'review_difficulty_Challenging', 'review_difficulty_Easy',
#        'review_difficulty_Very_Challenging', 'review_difficulty_Very_Easy',
#        'review_difficulty_unknown'],
#       dtype='object')

# %% [markdown]
# ### Building an Initial Regression Model

# %%
from statsmodels.formula.api import ols
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
import scipy.stats as stats
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(df_final)
print(train.info())
print(test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8152 entries, 7465 to 4927
# Data columns (total 99 columns):
# piece_count                                         8152 non-null float64
# list_price                                          8152 non-null float64
# num_reviews                                         7084 non-null float64
# play_star_rating                                    8152 non-null float64
# star_rating                                         8152 non-null float64
# val_star_rating                                     8152 non-null float64
# ages_10_14                                          8152 non-null uint8
# ages_10_16                                          8152 non-null uint8
# ages_10_21                                          8152 non-null uint8
# ages_11_16                                          8152 non-null uint8
# ages_12plus                                         8152 non-null uint8
# ages_12_16                                          8152 non-null uint8
# ages_14plus                                         8152 non-null uint8
# ages_16plus                                         8152 non-null uint8
# ages_1half_3                                        8152 non-null uint8
# ages_1half_5                                        8152 non-null uint8
# ages_2_5                                            8152 non-null uint8
# ages_4plus                                          8152 non-null uint8
# ages_4_7                                            8152 non-null uint8
# ages_4_99                                           8152 non-null uint8
# ages_5plus                                          8152 non-null uint8
# ages_5_12                                           8152 non-null uint8
# ages_5_8                                            8152 non-null uint8
# ages_6plus                                          8152 non-null uint8
# ages_6_12                                           8152 non-null uint8
# ages_6_14                                           8152 non-null uint8
# ages_7plus                                          8152 non-null uint8
# ages_7_12                                           8152 non-null uint8
# ages_7_14                                           8152 non-null uint8
# ages_8plus                                          8152 non-null uint8
# ages_8_12                                           8152 non-null uint8
# ages_8_14                                           8152 non-null uint8
# ages_9plus                                          8152 non-null uint8
# ages_9_12                                           8152 non-null uint8
# ages_9_14                                           8152 non-null uint8
# ages_9_16                                           8152 non-null uint8
# theme_name_Architecture                             8152 non-null uint8
# theme_name_BOOST                                    8152 non-null uint8
# theme_name_Blues_Helicopter_Pursuit                 8152 non-null uint8
# theme_name_BrickHeadz                               8152 non-null uint8
# theme_name_Carnotaurus_Gyrosphere_Escape            8152 non-null uint8
# theme_name_City                                     8152 non-null uint8
# theme_name_Classic                                  8152 non-null uint8
# theme_name_Creator_3_in_1                           8152 non-null uint8
# theme_name_Creator_Expert                           8152 non-null uint8
# theme_name_DC_Comics_Super_Heroes                   8152 non-null uint8
# theme_name_DC_Super_Hero_Girls                      8152 non-null uint8
# theme_name_DIMENSIONS                               8152 non-null uint8
# theme_name_DUPLO                                    8152 non-null uint8
# theme_name_Dilophosaurus_Outpost_Attack             8152 non-null uint8
# theme_name_Disney                                   8152 non-null uint8
# theme_name_Elves                                    8152 non-null uint8
# theme_name_Friends                                  8152 non-null uint8
# theme_name_Ghostbusters                             8152 non-null uint8
# theme_name_Ideas                                    8152 non-null uint8
# theme_name_Indoraptor_Rampage_at_Lockwood_Estate    8152 non-null uint8
# theme_name_Juniors                                  8152 non-null uint8
# theme_name_Jurassic_Park_Velociraptor_Chase         8152 non-null uint8
# theme_name_MINDSTORMS                               8152 non-null uint8
# theme_name_Marvel_Super_Heroes                      8152 non-null uint8
# theme_name_Minecraft                                8152 non-null uint8
# theme_name_Minifigures                              8152 non-null uint8
# theme_name_NEXO_KNIGHTS                             8152 non-null uint8
# theme_name_NINJAGO                                  8152 non-null uint8
# theme_name_Power_Functions                          8152 non-null uint8
# theme_name_Pteranodon_Chase                         8152 non-null uint8
# theme_name_SERIOUS_PLAY                             8152 non-null uint8
# theme_name_Speed_Champions                          8152 non-null uint8
# theme_name_Star_Wars                                8152 non-null uint8
# theme_name_Stygimoloch_Breakout                     8152 non-null uint8
# theme_name_T_rex_Transport                          8152 non-null uint8
# theme_name_THE_LEGO_BATMAN_MOVIE                    8152 non-null uint8
# theme_name_THE_LEGO_NINJAGO_MOVIE                   8152 non-null uint8
# theme_name_Technic                                  8152 non-null uint8
# country_AU                                          8152 non-null uint8
# country_BE                                          8152 non-null uint8
# country_CA                                          8152 non-null uint8
# country_CH                                          8152 non-null uint8
# country_CZ                                          8152 non-null uint8
# country_DE                                          8152 non-null uint8
# country_DN                                          8152 non-null uint8
# country_ES                                          8152 non-null uint8
# country_FI                                          8152 non-null uint8
# country_FR                                          8152 non-null uint8
# country_GB                                          8152 non-null uint8
# country_IE                                          8152 non-null uint8
# country_IT                                          8152 non-null uint8
# country_LU                                          8152 non-null uint8
# country_NL                                          8152 non-null uint8
# country_NO                                          8152 non-null uint8
# country_NZ                                          8152 non-null uint8
# country_PL                                          8152 non-null uint8
# country_PT                                          8152 non-null uint8
# country_US                                          8152 non-null uint8
# review_difficulty_Challenging                       8152 non-null uint8
# review_difficulty_Easy                              8152 non-null uint8
# review_difficulty_Very_Challenging                  8152 non-null uint8
# review_difficulty_Very_Easy                         8152 non-null uint8
# review_difficulty_unknown                           8152 non-null uint8
# dtypes: float64(6), uint8(93)
# memory usage: 1.2 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2718 entries, 1399 to 4039
# Data columns (total 99 columns):
# piece_count                                         2718 non-null float64
# list_price                                          2718 non-null float64
# num_reviews                                         2365 non-null float64
# play_star_rating                                    2718 non-null float64
# star_rating                                         2718 non-null float64
# val_star_rating                                     2718 non-null float64
# ages_10_14                                          2718 non-null uint8
# ages_10_16                                          2718 non-null uint8
# ages_10_21                                          2718 non-null uint8
# ages_11_16                                          2718 non-null uint8
# ages_12plus                                         2718 non-null uint8
# ages_12_16                                          2718 non-null uint8
# ages_14plus                                         2718 non-null uint8
# ages_16plus                                         2718 non-null uint8
# ages_1half_3                                        2718 non-null uint8
# ages_1half_5                                        2718 non-null uint8
# ages_2_5                                            2718 non-null uint8
# ages_4plus                                          2718 non-null uint8
# ages_4_7                                            2718 non-null uint8
# ages_4_99                                           2718 non-null uint8
# ages_5plus                                          2718 non-null uint8
# ages_5_12                                           2718 non-null uint8
# ages_5_8                                            2718 non-null uint8
# ages_6plus                                          2718 non-null uint8
# ages_6_12                                           2718 non-null uint8
# ages_6_14                                           2718 non-null uint8
# ages_7plus                                          2718 non-null uint8
# ages_7_12                                           2718 non-null uint8
# ages_7_14                                           2718 non-null uint8
# ages_8plus                                          2718 non-null uint8
# ages_8_12                                           2718 non-null uint8
# ages_8_14                                           2718 non-null uint8
# ages_9plus                                          2718 non-null uint8
# ages_9_12                                           2718 non-null uint8
# ages_9_14                                           2718 non-null uint8
# ages_9_16                                           2718 non-null uint8
# theme_name_Architecture                             2718 non-null uint8
# theme_name_BOOST                                    2718 non-null uint8
# theme_name_Blues_Helicopter_Pursuit                 2718 non-null uint8
# theme_name_BrickHeadz                               2718 non-null uint8
# theme_name_Carnotaurus_Gyrosphere_Escape            2718 non-null uint8
# theme_name_City                                     2718 non-null uint8
# theme_name_Classic                                  2718 non-null uint8
# theme_name_Creator_3_in_1                           2718 non-null uint8
# theme_name_Creator_Expert                           2718 non-null uint8
# theme_name_DC_Comics_Super_Heroes                   2718 non-null uint8
# theme_name_DC_Super_Hero_Girls                      2718 non-null uint8
# theme_name_DIMENSIONS                               2718 non-null uint8
# theme_name_DUPLO                                    2718 non-null uint8
# theme_name_Dilophosaurus_Outpost_Attack             2718 non-null uint8
# theme_name_Disney                                   2718 non-null uint8
# theme_name_Elves                                    2718 non-null uint8
# theme_name_Friends                                  2718 non-null uint8
# theme_name_Ghostbusters                             2718 non-null uint8
# theme_name_Ideas                                    2718 non-null uint8
# theme_name_Indoraptor_Rampage_at_Lockwood_Estate    2718 non-null uint8
# theme_name_Juniors                                  2718 non-null uint8
# theme_name_Jurassic_Park_Velociraptor_Chase         2718 non-null uint8
# theme_name_MINDSTORMS                               2718 non-null uint8
# theme_name_Marvel_Super_Heroes                      2718 non-null uint8
# theme_name_Minecraft                                2718 non-null uint8
# theme_name_Minifigures                              2718 non-null uint8
# theme_name_NEXO_KNIGHTS                             2718 non-null uint8
# theme_name_NINJAGO                                  2718 non-null uint8
# theme_name_Power_Functions                          2718 non-null uint8
# theme_name_Pteranodon_Chase                         2718 non-null uint8
# theme_name_SERIOUS_PLAY                             2718 non-null uint8
# theme_name_Speed_Champions                          2718 non-null uint8
# theme_name_Star_Wars                                2718 non-null uint8
# theme_name_Stygimoloch_Breakout                     2718 non-null uint8
# theme_name_T_rex_Transport                          2718 non-null uint8
# theme_name_THE_LEGO_BATMAN_MOVIE                    2718 non-null uint8
# theme_name_THE_LEGO_NINJAGO_MOVIE                   2718 non-null uint8
# theme_name_Technic                                  2718 non-null uint8
# country_AU                                          2718 non-null uint8
# country_BE                                          2718 non-null uint8
# country_CA                                          2718 non-null uint8
# country_CH                                          2718 non-null uint8
# country_CZ                                          2718 non-null uint8
# country_DE                                          2718 non-null uint8
# country_DN                                          2718 non-null uint8
# country_ES                                          2718 non-null uint8
# country_FI                                          2718 non-null uint8
# country_FR                                          2718 non-null uint8
# country_GB                                          2718 non-null uint8
# country_IE                                          2718 non-null uint8
# country_IT                                          2718 non-null uint8
# country_LU                                          2718 non-null uint8
# country_NL                                          2718 non-null uint8
# country_NO                                          2718 non-null uint8
# country_NZ                                          2718 non-null uint8
# country_PL                                          2718 non-null uint8
# country_PT                                          2718 non-null uint8
# country_US                                          2718 non-null uint8
# review_difficulty_Challenging                       2718 non-null uint8
# review_difficulty_Easy                              2718 non-null uint8
# review_difficulty_Very_Challenging                  2718 non-null uint8
# review_difficulty_Very_Easy                         2718 non-null uint8
# review_difficulty_unknown                           2718 non-null uint8
# dtypes: float64(6), uint8(93)
# memory usage: 395.5 KB
# None

# %%
X = train.drop('list_price', axis=1)

# %%
formula = 'list_price~' + '+'.join(X.columns)

# %%
model = ols(formula=formula, data=train).fit()

# %%
summary = model.summary()
summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             list_price   R-squared:                       0.793
# Model:                            OLS   Adj. R-squared:                  0.790
# Method:                 Least Squares   F-statistic:                     293.6
# Date:                Thu, 12 Nov 2020   Prob (F-statistic):               0.00
# Time:                        18:28:52   Log-Likelihood:                -37232.
# No. Observations:                7084   AIC:                         7.465e+04
# Df Residuals:                    6992   BIC:                         7.528e+04
# Df Model:                          91
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                           59.9483     24.579      2.439      0.015      11.765     108.131
# piece_count                                        296.7747      7.216     41.128      0.000     282.629     310.920
# num_reviews                                         32.4825      4.153      7.822      0.000      24.342      40.623
# play_star_rating                                    59.8367      8.163      7.330      0.000      43.834      75.839
# star_rating                                         -4.9512      7.892     -0.627      0.530     -20.423      10.520
# val_star_rating                                    -96.3072      7.814    -12.324      0.000    -111.626     -80.989
# ages_10_14                                        -194.1715     14.929    -13.006      0.000    -223.437    -164.906
# ages_10_16                                        -116.6008     11.353    -10.270      0.000    -138.856     -94.345
# ages_10_21                                          14.5731      8.893      1.639      0.101      -2.860      32.006
# ages_11_16                                         -46.8216     12.807     -3.656      0.000     -71.927     -21.716
# ages_12plus                                         54.7981      9.627      5.692      0.000      35.927      73.669
# ages_12_16                                         -53.3224     13.648     -3.907      0.000     -80.076     -26.569
# ages_14plus                                          0.9516     10.488      0.091      0.928     -19.609      21.512
# ages_16plus                                        185.7551     11.259     16.498      0.000     163.683     207.827
# ages_1half_3                                       -26.2590      8.872     -2.960      0.003     -43.651      -8.867
# ages_1half_5                                       -25.8360      7.965     -3.244      0.001     -41.450     -10.222
# ages_2_5                                           -22.9438      6.743     -3.402      0.001     -36.163      -9.725
# ages_4plus                                          16.4699     11.365      1.449      0.147      -5.808      38.748
# ages_4_7                                           -42.2515      8.909     -4.742      0.000     -59.717     -24.786
# ages_4_99                                          -84.5521      8.995     -9.400      0.000    -102.184     -66.920
# ages_5plus                                         -57.4873     12.621     -4.555      0.000     -82.228     -32.747
# ages_5_12                                         -161.8546     10.907    -14.840      0.000    -183.235    -140.474
# ages_5_8                                           -66.0714     10.889     -6.068      0.000     -87.417     -44.726
# ages_6plus                                        -141.2375     12.671    -11.146      0.000    -166.077    -116.398
# ages_6_12                                         -155.9912     10.390    -15.014      0.000    -176.358    -135.625
# ages_6_14                                         -122.0258     11.470    -10.639      0.000    -144.510     -99.542
# ages_7plus                                        9.437e-14   1.85e-14      5.096      0.000    5.81e-14    1.31e-13
# ages_7_12                                         -158.7079     10.565    -15.023      0.000    -179.418    -137.998
# ages_7_14                                         -148.1435     10.223    -14.491      0.000    -168.184    -128.103
# ages_8plus                                        -105.3036      9.747    -10.804      0.000    -124.410     -86.197
# ages_8_12                                         -149.8853     10.818    -13.855      0.000    -171.092    -128.679
# ages_8_14                                         -149.2583     10.279    -14.521      0.000    -169.408    -129.108
# ages_9plus                                          -7.1143     14.067     -0.506      0.613     -34.689      20.461
# ages_9_12                                         -166.8327     13.482    -12.375      0.000    -193.261    -140.405
# ages_9_14                                         -129.4779     10.465    -12.372      0.000    -149.993    -108.963
# ages_9_16                                         -122.8139     12.348     -9.946      0.000    -147.019     -98.609
# theme_name_Architecture                           -235.8856     22.853    -10.322      0.000    -280.685    -191.086
# theme_name_BOOST                                    76.0878     24.728      3.077      0.002      27.614     124.561
# theme_name_Blues_Helicopter_Pursuit               5.454e-13   5.62e-14      9.709      0.000    4.35e-13    6.56e-13
# theme_name_BrickHeadz                             -162.4102     23.559     -6.894      0.000    -208.592    -116.228
# theme_name_Carnotaurus_Gyrosphere_Escape            26.5843     24.571      1.082      0.279     -21.583      74.752
# theme_name_City                                      2.0073     21.150      0.095      0.924     -39.453      43.467
# theme_name_Classic                                 -68.0823     16.244     -4.191      0.000     -99.925     -36.239
# theme_name_Creator_3_in_1                          -22.8869     21.244     -1.077      0.281     -64.532      18.758
# theme_name_Creator_Expert                         -295.2423     21.930    -13.463      0.000    -338.231    -252.254
# theme_name_DC_Comics_Super_Heroes                  -15.2153     21.471     -0.709      0.479     -57.304      26.874
# theme_name_DC_Super_Hero_Girls                      -7.5407     25.057     -0.301      0.763     -56.660      41.578
# theme_name_DIMENSIONS                                7.1902     21.496      0.334      0.738     -34.949      49.329
# theme_name_DUPLO                                   -75.0388     17.832     -4.208      0.000    -109.994     -40.083
# theme_name_Dilophosaurus_Outpost_Attack             10.2241     24.245      0.422      0.673     -37.304      57.752
# theme_name_Disney                                  -21.2705     21.277     -1.000      0.318     -62.981      20.440
# theme_name_Elves                                   -22.0814     21.541     -1.025      0.305     -64.308      20.146
# theme_name_Friends                                 -24.2322     21.105     -1.148      0.251     -65.605      17.140
# theme_name_Ghostbusters                            -93.3234     24.401     -3.825      0.000    -141.157     -45.490
# theme_name_Ideas                                  -189.9823     22.672     -8.380      0.000    -234.426    -145.538
# theme_name_Indoraptor_Rampage_at_Lockwood_Estate    58.7688     24.735      2.376      0.018      10.282     107.256
# theme_name_Juniors                                -108.3229     16.084     -6.735      0.000    -139.852     -76.793
# theme_name_Jurassic_Park_Velociraptor_Chase        -11.7207     24.412     -0.480      0.631     -59.575      36.134
# theme_name_MINDSTORMS                               46.3507     23.836      1.945      0.052      -0.376      93.077
# theme_name_Marvel_Super_Heroes                     -22.9210     21.219     -1.080      0.280     -64.516      18.674
# theme_name_Minecraft                               -54.4103     22.088     -2.463      0.014     -97.710     -11.111
# theme_name_Minifigures                             -57.4873     12.621     -4.555      0.000     -82.228     -32.747
# theme_name_NEXO_KNIGHTS                            -34.3325     21.682     -1.583      0.113     -76.837       8.172
# theme_name_NINJAGO                                 -45.1360     21.545     -2.095      0.036     -87.371      -2.901
# theme_name_Power_Functions                          46.9035     25.256      1.857      0.063      -2.607      96.414
# theme_name_Pteranodon_Chase                        -21.2969     25.081     -0.849      0.396     -70.464      27.870
# theme_name_SERIOUS_PLAY                            342.1362     23.075     14.827      0.000     296.903     387.369
# theme_name_Speed_Champions                         -22.3214     21.433     -1.041      0.298     -64.336      19.693
# theme_name_Star_Wars                                -5.5023     21.086     -0.261      0.794     -46.837      35.833
# theme_name_Stygimoloch_Breakout                     -1.6635     25.267     -0.066      0.948     -51.194      47.867
# theme_name_T_rex_Transport                        6.656e-15   1.67e-14      0.399      0.690    -2.6e-14    3.93e-14
# theme_name_THE_LEGO_BATMAN_MOVIE                   -22.1662     21.248     -1.043      0.297     -63.819      19.487
# theme_name_THE_LEGO_NINJAGO_MOVIE                  -37.5136     21.318     -1.760      0.078     -79.303       4.276
# theme_name_Technic                                 -37.9673     21.356     -1.778      0.075     -79.832       3.897
# country_AU                                          -4.8354      3.629     -1.332      0.183     -11.950       2.279
# country_BE                                           3.4420      3.647      0.944      0.345      -3.707      10.591
# country_CA                                         -14.1081      3.331     -4.235      0.000     -20.639      -7.578
# country_CH                                          -2.8946      3.566     -0.812      0.417      -9.886       4.097
# country_CZ                                           5.2768      3.665      1.440      0.150      -1.907      12.461
# country_DE                                           1.5655      3.650      0.429      0.668      -5.589       8.720
# country_DN                                         -13.4751      3.641     -3.701      0.000     -20.613      -6.338
# country_ES                                           3.0094      3.650      0.825      0.410      -4.145      10.164
# country_FI                                          12.6542      3.665      3.452      0.001       5.469      19.840
# country_FR                                           1.2434      3.608      0.345      0.730      -5.829       8.315
# country_GB                                           0.7708      3.595      0.214      0.830      -6.276       7.818
# country_IE                                          -0.5593      3.607     -0.155      0.877      -7.631       6.512
# country_IT                                           1.3433      3.649      0.368      0.713      -5.811       8.497
# country_LU                                           4.4053      3.650      1.207      0.228      -2.750      11.561
# country_NL                                           1.8744      3.577      0.524      0.600      -5.138       8.887
# country_NO                                          14.2474      3.736      3.814      0.000       6.924      21.570
# country_NZ                                           5.3983      3.606      1.497      0.134      -1.670      12.467
# country_PL                                           2.2167      3.758      0.590      0.555      -5.149       9.583
# country_PT                                           0.2598      3.641      0.071      0.943      -6.878       7.398
# country_US                                          -9.5608      3.344     -2.859      0.004     -16.116      -3.006
# review_difficulty_Challenging                       31.9851      2.636     12.133      0.000      26.817      37.153
# review_difficulty_Easy                              -9.0798      1.619     -5.607      0.000     -12.254      -5.905
# review_difficulty_Very_Challenging                 -13.2674     12.733     -1.042      0.297     -38.228      11.694
# review_difficulty_Very_Easy                         10.0851      2.715      3.715      0.000       4.763      15.407
# review_difficulty_unknown                           -2.5378      3.474     -0.730      0.465      -9.349       4.273
# ==============================================================================
# Omnibus:                     4204.084   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           446295.886
# Skew:                           1.928   Prob(JB):                         0.00
# Kurtosis:                      41.693   Cond. No.                     2.12e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.75e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
ptable = summary.tables[1]
df_p = pd.DataFrame(ptable.data)
df_p.head()
# Out:
#                   0           1          2          3       4          5  \
# 0                          coef    std err          t   P>|t|     [0.025
# 1         Intercept     59.9483     24.579      2.439   0.015     11.765
# 2       piece_count    296.7747      7.216     41.128   0.000    282.629
# 3       num_reviews     32.4825      4.153      7.822   0.000     24.342
# 4  play_star_rating     59.8367      8.163      7.330   0.000     43.834
#
#            6
# 0     0.975]
# 1    108.131
# 2    310.920
# 3     40.623
# 4     75.839

# %%
df_p.drop(0, inplace=True)

# %%
df_p[4] = df_p[4].map(lambda x: float(x))

# %%
relevant_list = list(df_p[df_p[4] < .05][0][1:])
print(relevant_list)
# Out:
# ['piece_count', 'num_reviews', 'play_star_rating', 'val_star_rating', 'ages_10_14', 'ages_10_16', 'ages_11_16', 'ages_12plus', 'ages_12_16', 'ages_16plus', 'ages_1half_3', 'ages_1half_5', 'ages_2_5', 'ages_4_7', 'ages_4_99', 'ages_5plus', 'ages_5_12', 'ages_5_8', 'ages_6plus', 'ages_6_12', 'ages_6_14', 'ages_7plus', 'ages_7_12', 'ages_7_14', 'ages_8plus', 'ages_8_12', 'ages_8_14', 'ages_9_12', 'ages_9_14', 'ages_9_16', 'theme_name_Architecture', 'theme_name_BOOST', 'theme_name_Blues_Helicopter_Pursuit', 'theme_name_BrickHeadz', 'theme_name_Classic', 'theme_name_Creator_Expert', 'theme_name_DUPLO', 'theme_name_Ghostbusters', 'theme_name_Ideas', 'theme_name_Indoraptor_Rampage_at_Lockwood_Estate', 'theme_name_Juniors', 'theme_name_Minecraft', 'theme_name_Minifigures', 'theme_name_NINJAGO', 'theme_name_SERIOUS_PLAY', 'country_CA', 'country_DN', 'country_FI', 'country_NO', 'country_US', 'review_difficulty_Challenging', 'review_difficulty_Easy', 'review_difficulty_Very_Easy']

# %%
formula = 'list_price~' + '+'.join(relevant_list)

# %%
model2 = ols(formula=formula, data=train).fit()

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             list_price   R-squared:                       0.780
# Model:                            OLS   Adj. R-squared:                  0.779
# Method:                 Least Squares   F-statistic:                     520.5
# Date:                Thu, 12 Nov 2020   Prob (F-statistic):               0.00
# Time:                        18:28:52   Log-Likelihood:                -37436.
# No. Observations:                7084   AIC:                         7.497e+04
# Df Residuals:                    7035   BIC:                         7.531e+04
# Df Model:                          48
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                           99.6241      7.152     13.930      0.000      85.604     113.644
# piece_count                                        250.0107      5.273     47.413      0.000     239.674     260.347
# num_reviews                                         35.7169      3.552     10.056      0.000      28.755      42.679
# play_star_rating                                    71.8748      7.089     10.139      0.000      57.978      85.771
# val_star_rating                                   -111.9404      6.138    -18.239      0.000    -123.972     -99.909
# ages_10_14                                        -206.6077     11.481    -17.996      0.000    -229.114    -184.102
# ages_10_16                                        -151.5610      5.700    -26.588      0.000    -162.736    -140.386
# ages_11_16                                         -85.3762      7.947    -10.743      0.000    -100.955     -69.797
# ages_12plus                                         47.8098      7.278      6.569      0.000      33.542      62.077
# ages_12_16                                         -82.3144      9.721     -8.468      0.000    -101.370     -63.259
# ages_16plus                                        166.9756      6.613     25.251      0.000     154.013     179.939
# ages_1half_3                                       -30.3233      6.803     -4.457      0.000     -43.660     -16.987
# ages_1half_5                                       -35.9979      5.503     -6.541      0.000     -46.786     -25.209
# ages_2_5                                           -26.5800      3.504     -7.585      0.000     -33.450     -19.710
# ages_4_7                                           -50.4442      4.522    -11.157      0.000     -59.308     -41.581
# ages_4_99                                          -77.8030     12.575     -6.187      0.000    -102.454     -53.152
# ages_5plus                                         -72.7259      4.828    -15.064      0.000     -82.190     -63.262
# ages_5_12                                         -179.0999      3.858    -46.427      0.000    -186.662    -171.538
# ages_5_8                                           -66.5418      7.800     -8.531      0.000     -81.832     -51.251
# ages_6plus                                        -178.1970      7.771    -22.930      0.000    -193.431    -162.963
# ages_6_12                                         -182.3128      3.638    -50.115      0.000    -189.444    -175.182
# ages_6_14                                         -166.7702      6.754    -24.691      0.000    -180.011    -153.530
# ages_7plus                                        1.262e-13   1.57e-14      8.025      0.000    9.54e-14    1.57e-13
# ages_7_12                                         -182.8029      4.013    -45.551      0.000    -190.670    -174.936
# ages_7_14                                         -179.8095      3.700    -48.594      0.000    -187.063    -172.556
# ages_8plus                                        -122.8010      7.254    -16.929      0.000    -137.020    -108.582
# ages_8_12                                         -173.8525      4.589    -37.889      0.000    -182.847    -164.858
# ages_8_14                                         -178.1408      3.716    -47.941      0.000    -185.425    -170.857
# ages_9_12                                         -199.4335      8.861    -22.507      0.000    -216.804    -182.063
# ages_9_14                                         -154.1519      4.166    -37.004      0.000    -162.318    -145.986
# ages_9_16                                         -154.0549      6.556    -23.499      0.000    -166.906    -141.204
# theme_name_Architecture                           -235.9219      8.164    -28.898      0.000    -251.925    -219.918
# theme_name_BOOST                                    94.8041     13.138      7.216      0.000      69.051     120.558
# theme_name_Blues_Helicopter_Pursuit               6.029e-14   4.86e-15     12.419      0.000    5.08e-14    6.98e-14
# theme_name_BrickHeadz                             -173.9181      4.659    -37.329      0.000    -183.051    -164.785
# theme_name_Classic                                 -92.6398     12.484     -7.421      0.000    -117.112     -68.167
# theme_name_Creator_Expert                         -277.5301      6.157    -45.076      0.000    -289.600    -265.461
# theme_name_DUPLO                                   -92.9012      3.704    -25.083      0.000    -100.162     -85.641
# theme_name_Ghostbusters                            -71.0893     12.603     -5.641      0.000     -95.795     -46.384
# theme_name_Ideas                                  -195.9843      6.175    -31.737      0.000    -208.090    -183.879
# theme_name_Indoraptor_Rampage_at_Lockwood_Estate    76.5575     13.271      5.769      0.000      50.541     102.574
# theme_name_Juniors                                -116.9860      4.463    -26.213      0.000    -125.735    -108.237
# theme_name_Minecraft                               -42.6563      6.032     -7.072      0.000     -54.480     -30.832
# theme_name_Minifigures                             -72.7259      4.828    -15.064      0.000     -82.190     -63.262
# theme_name_NINJAGO                                 -25.3193      4.565     -5.547      0.000     -34.267     -16.371
# theme_name_SERIOUS_PLAY                            376.2258      9.206     40.868      0.000     358.179     394.272
# country_CA                                         -16.6341      2.290     -7.262      0.000     -21.124     -12.144
# country_DN                                         -14.1254      2.757     -5.123      0.000     -19.530      -8.720
# country_FI                                          11.3217      2.787      4.062      0.000       5.858      16.785
# country_NO                                          12.3779      2.884      4.292      0.000       6.725      18.031
# country_US                                         -12.2345      2.314     -5.288      0.000     -16.770      -7.699
# review_difficulty_Challenging                       30.6982      2.540     12.084      0.000      25.718      35.678
# review_difficulty_Easy                              -8.8866      1.476     -6.020      0.000     -11.780      -5.993
# review_difficulty_Very_Easy                          9.9345      2.600      3.820      0.000       4.837      15.032
# ==============================================================================
# Omnibus:                     4190.320   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           453049.341
# Skew:                           1.912   Prob(JB):                         0.00
# Kurtosis:                      41.991   Cond. No.                     1.20e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.68e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
p_table2 = summary.tables[1]
p_table2 = pd.DataFrame(p_table2.data)
p_table2.columns = p_table2.iloc[0]
p_table2 = p_table2.drop(0)
p_table2 = p_table2.set_index(p_table2.columns[0])
p_table2['P>|t|'] = p_table2['P>|t|'].astype(float)
x_cols = list(p_table2[p_table2['P>|t|'] < 0.05].index)
x_cols.remove('Intercept')
print(len(p_table2), len(x_cols))
print(x_cols[:5])
p_table2.head()
# Out:
# 99 53
# ['piece_count', 'num_reviews', 'play_star_rating', 'val_star_rating', 'ages_10_14']
# 0                       coef    std err          t  P>|t|     [0.025  \
#
# Intercept            59.9483     24.579      2.439  0.015     11.765
# piece_count         296.7747      7.216     41.128  0.000    282.629
# num_reviews          32.4825      4.153      7.822  0.000     24.342
# play_star_rating     59.8367      8.163      7.330  0.000     43.834
# star_rating          -4.9512      7.892     -0.627  0.530    -20.423
#
# 0                    0.975]
#
# Intercept           108.131
# piece_count         310.920
# num_reviews          40.623
# play_star_rating     75.839
# star_rating          10.520

# %%
formula = 'list_price~' + '+'.join(x_cols) 
model3 = ols(formula=formula, data=train).fit()
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             list_price   R-squared:                       0.780
# Model:                            OLS   Adj. R-squared:                  0.779
# Method:                 Least Squares   F-statistic:                     520.5
# Date:                Thu, 12 Nov 2020   Prob (F-statistic):               0.00
# Time:                        18:28:53   Log-Likelihood:                -37436.
# No. Observations:                7084   AIC:                         7.497e+04
# Df Residuals:                    7035   BIC:                         7.531e+04
# Df Model:                          48
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                           99.6241      7.152     13.930      0.000      85.604     113.644
# piece_count                                        250.0107      5.273     47.413      0.000     239.674     260.347
# num_reviews                                         35.7169      3.552     10.056      0.000      28.755      42.679
# play_star_rating                                    71.8748      7.089     10.139      0.000      57.978      85.771
# val_star_rating                                   -111.9404      6.138    -18.239      0.000    -123.972     -99.909
# ages_10_14                                        -206.6077     11.481    -17.996      0.000    -229.114    -184.102
# ages_10_16                                        -151.5610      5.700    -26.588      0.000    -162.736    -140.386
# ages_11_16                                         -85.3762      7.947    -10.743      0.000    -100.955     -69.797
# ages_12plus                                         47.8098      7.278      6.569      0.000      33.542      62.077
# ages_12_16                                         -82.3144      9.721     -8.468      0.000    -101.370     -63.259
# ages_16plus                                        166.9756      6.613     25.251      0.000     154.013     179.939
# ages_1half_3                                       -30.3233      6.803     -4.457      0.000     -43.660     -16.987
# ages_1half_5                                       -35.9979      5.503     -6.541      0.000     -46.786     -25.209
# ages_2_5                                           -26.5800      3.504     -7.585      0.000     -33.450     -19.710
# ages_4_7                                           -50.4442      4.522    -11.157      0.000     -59.308     -41.581
# ages_4_99                                          -77.8030     12.575     -6.187      0.000    -102.454     -53.152
# ages_5plus                                         -72.7259      4.828    -15.064      0.000     -82.190     -63.262
# ages_5_12                                         -179.0999      3.858    -46.427      0.000    -186.662    -171.538
# ages_5_8                                           -66.5418      7.800     -8.531      0.000     -81.832     -51.251
# ages_6plus                                        -178.1970      7.771    -22.930      0.000    -193.431    -162.963
# ages_6_12                                         -182.3128      3.638    -50.115      0.000    -189.444    -175.182
# ages_6_14                                         -166.7702      6.754    -24.691      0.000    -180.011    -153.530
# ages_7plus                                        1.262e-13   1.57e-14      8.025      0.000    9.54e-14    1.57e-13
# ages_7_12                                         -182.8029      4.013    -45.551      0.000    -190.670    -174.936
# ages_7_14                                         -179.8095      3.700    -48.594      0.000    -187.063    -172.556
# ages_8plus                                        -122.8010      7.254    -16.929      0.000    -137.020    -108.582
# ages_8_12                                         -173.8525      4.589    -37.889      0.000    -182.847    -164.858
# ages_8_14                                         -178.1408      3.716    -47.941      0.000    -185.425    -170.857
# ages_9_12                                         -199.4335      8.861    -22.507      0.000    -216.804    -182.063
# ages_9_14                                         -154.1519      4.166    -37.004      0.000    -162.318    -145.986
# ages_9_16                                         -154.0549      6.556    -23.499      0.000    -166.906    -141.204
# theme_name_Architecture                           -235.9219      8.164    -28.898      0.000    -251.925    -219.918
# theme_name_BOOST                                    94.8041     13.138      7.216      0.000      69.051     120.558
# theme_name_Blues_Helicopter_Pursuit               6.029e-14   4.86e-15     12.419      0.000    5.08e-14    6.98e-14
# theme_name_BrickHeadz                             -173.9181      4.659    -37.329      0.000    -183.051    -164.785
# theme_name_Classic                                 -92.6398     12.484     -7.421      0.000    -117.112     -68.167
# theme_name_Creator_Expert                         -277.5301      6.157    -45.076      0.000    -289.600    -265.461
# theme_name_DUPLO                                   -92.9012      3.704    -25.083      0.000    -100.162     -85.641
# theme_name_Ghostbusters                            -71.0893     12.603     -5.641      0.000     -95.795     -46.384
# theme_name_Ideas                                  -195.9843      6.175    -31.737      0.000    -208.090    -183.879
# theme_name_Indoraptor_Rampage_at_Lockwood_Estate    76.5575     13.271      5.769      0.000      50.541     102.574
# theme_name_Juniors                                -116.9860      4.463    -26.213      0.000    -125.735    -108.237
# theme_name_Minecraft                               -42.6563      6.032     -7.072      0.000     -54.480     -30.832
# theme_name_Minifigures                             -72.7259      4.828    -15.064      0.000     -82.190     -63.262
# theme_name_NINJAGO                                 -25.3193      4.565     -5.547      0.000     -34.267     -16.371
# theme_name_SERIOUS_PLAY                            376.2258      9.206     40.868      0.000     358.179     394.272
# country_CA                                         -16.6341      2.290     -7.262      0.000     -21.124     -12.144
# country_DN                                         -14.1254      2.757     -5.123      0.000     -19.530      -8.720
# country_FI                                          11.3217      2.787      4.062      0.000       5.858      16.785
# country_NO                                          12.3779      2.884      4.292      0.000       6.725      18.031
# country_US                                         -12.2345      2.314     -5.288      0.000     -16.770      -7.699
# review_difficulty_Challenging                       30.6982      2.540     12.084      0.000      25.718      35.678
# review_difficulty_Easy                              -8.8866      1.476     -6.020      0.000     -11.780      -5.993
# review_difficulty_Very_Easy                          9.9345      2.600      3.820      0.000       4.837      15.032
# ==============================================================================
# Omnibus:                     4190.320   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           453049.341
# Skew:                           1.912   Prob(JB):                         0.00
# Kurtosis:                      41.991   Cond. No.                     1.20e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.68e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# ## Check for Normality

# %%
#using a Q-Q Plot from StatsModels
fig = sm.qqplot(model3.resid, line='45', fit=True)

# %% [markdown]
# ## Check Homoscedasticity ##

# %%
len(model3.predict(train[x_cols]))
# Out:
# 8152

# %%
len(model3.resid)
# Out:
# 7084

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8152 entries, 7465 to 4927
# Data columns (total 99 columns):
# piece_count                                         8152 non-null float64
# list_price                                          8152 non-null float64
# num_reviews                                         7084 non-null float64
# play_star_rating                                    8152 non-null float64
# star_rating                                         8152 non-null float64
# val_star_rating                                     8152 non-null float64
# ages_10_14                                          8152 non-null uint8
# ages_10_16                                          8152 non-null uint8
# ages_10_21                                          8152 non-null uint8
# ages_11_16                                          8152 non-null uint8
# ages_12plus                                         8152 non-null uint8
# ages_12_16                                          8152 non-null uint8
# ages_14plus                                         8152 non-null uint8
# ages_16plus                                         8152 non-null uint8
# ages_1half_3                                        8152 non-null uint8
# ages_1half_5                                        8152 non-null uint8
# ages_2_5                                            8152 non-null uint8
# ages_4plus                                          8152 non-null uint8
# ages_4_7                                            8152 non-null uint8
# ages_4_99                                           8152 non-null uint8
# ages_5plus                                          8152 non-null uint8
# ages_5_12                                           8152 non-null uint8
# ages_5_8                                            8152 non-null uint8
# ages_6plus                                          8152 non-null uint8
# ages_6_12                                           8152 non-null uint8
# ages_6_14                                           8152 non-null uint8
# ages_7plus                                          8152 non-null uint8
# ages_7_12                                           8152 non-null uint8
# ages_7_14                                           8152 non-null uint8
# ages_8plus                                          8152 non-null uint8
# ages_8_12                                           8152 non-null uint8
# ages_8_14                                           8152 non-null uint8
# ages_9plus                                          8152 non-null uint8
# ages_9_12                                           8152 non-null uint8
# ages_9_14                                           8152 non-null uint8
# ages_9_16                                           8152 non-null uint8
# theme_name_Architecture                             8152 non-null uint8
# theme_name_BOOST                                    8152 non-null uint8
# theme_name_Blues_Helicopter_Pursuit                 8152 non-null uint8
# theme_name_BrickHeadz                               8152 non-null uint8
# theme_name_Carnotaurus_Gyrosphere_Escape            8152 non-null uint8
# theme_name_City                                     8152 non-null uint8
# theme_name_Classic                                  8152 non-null uint8
# theme_name_Creator_3_in_1                           8152 non-null uint8
# theme_name_Creator_Expert                           8152 non-null uint8
# theme_name_DC_Comics_Super_Heroes                   8152 non-null uint8
# theme_name_DC_Super_Hero_Girls                      8152 non-null uint8
# theme_name_DIMENSIONS                               8152 non-null uint8
# theme_name_DUPLO                                    8152 non-null uint8
# theme_name_Dilophosaurus_Outpost_Attack             8152 non-null uint8
# theme_name_Disney                                   8152 non-null uint8
# theme_name_Elves                                    8152 non-null uint8
# theme_name_Friends                                  8152 non-null uint8
# theme_name_Ghostbusters                             8152 non-null uint8
# theme_name_Ideas                                    8152 non-null uint8
# theme_name_Indoraptor_Rampage_at_Lockwood_Estate    8152 non-null uint8
# theme_name_Juniors                                  8152 non-null uint8
# theme_name_Jurassic_Park_Velociraptor_Chase         8152 non-null uint8
# theme_name_MINDSTORMS                               8152 non-null uint8
# theme_name_Marvel_Super_Heroes                      8152 non-null uint8
# theme_name_Minecraft                                8152 non-null uint8
# theme_name_Minifigures                              8152 non-null uint8
# theme_name_NEXO_KNIGHTS                             8152 non-null uint8
# theme_name_NINJAGO                                  8152 non-null uint8
# theme_name_Power_Functions                          8152 non-null uint8
# theme_name_Pteranodon_Chase                         8152 non-null uint8
# theme_name_SERIOUS_PLAY                             8152 non-null uint8
# theme_name_Speed_Champions                          8152 non-null uint8
# theme_name_Star_Wars                                8152 non-null uint8
# theme_name_Stygimoloch_Breakout                     8152 non-null uint8
# theme_name_T_rex_Transport                          8152 non-null uint8
# theme_name_THE_LEGO_BATMAN_MOVIE                    8152 non-null uint8
# theme_name_THE_LEGO_NINJAGO_MOVIE                   8152 non-null uint8
# theme_name_Technic                                  8152 non-null uint8
# country_AU                                          8152 non-null uint8
# country_BE                                          8152 non-null uint8
# country_CA                                          8152 non-null uint8
# country_CH                                          8152 non-null uint8
# country_CZ                                          8152 non-null uint8
# country_DE                                          8152 non-null uint8
# country_DN                                          8152 non-null uint8
# country_ES                                          8152 non-null uint8
# country_FI                                          8152 non-null uint8
# country_FR                                          8152 non-null uint8
# country_GB                                          8152 non-null uint8
# country_IE                                          8152 non-null uint8
# country_IT                                          8152 non-null uint8
# country_LU                                          8152 non-null uint8
# country_NL                                          8152 non-null uint8
# country_NO                                          8152 non-null uint8
# country_NZ                                          8152 non-null uint8
# country_PL                                          8152 non-null uint8
# country_PT                                          8152 non-null uint8
# country_US                                          8152 non-null uint8
# review_difficulty_Challenging                       8152 non-null uint8
# review_difficulty_Easy                              8152 non-null uint8
# review_difficulty_Very_Challenging                  8152 non-null uint8
# review_difficulty_Very_Easy                         8152 non-null uint8
# review_difficulty_unknown                           8152 non-null uint8
# dtypes: float64(6), uint8(93)
# memory usage: 1.2 MB

# %%
y_hat = train['list_price'] - model3.predict(train[x_cols])
len(y_hat)
# Out:
# 8152

# %%
plt.scatter(model3.predict(train[x_cols]), y_hat)
plt.plot(model3.predict(train[x_cols]), [0 for i in range(len(train))])

# %%
#Remove outliers

train.describe()
# Out:
#        piece_count   list_price  num_reviews  play_star_rating  star_rating  \
# count  8152.000000  8152.000000  7084.000000       8152.000000  8152.000000
# mean      0.594678    68.125178     0.317891          0.911085     0.896245
# std       0.178244    96.166006     0.223687          0.099217     0.118593
# min       0.000000     2.272400     0.000000          0.000000     0.000000
# 25%       0.512394    21.947800     0.117376          0.891668     0.852373
# 50%       0.606635    36.587800     0.303412          0.934536     0.918385
# 75%       0.708965    73.187800     0.446892          0.961555     0.980225
# max       1.000000  1104.870000     1.000000          1.000000     1.000000
#
#        val_star_rating   ages_10_14   ages_10_16   ages_10_21   ages_11_16  \
# count      8152.000000  8152.000000  8152.000000  8152.000000  8152.000000
# mean          0.888895     0.002331     0.013126     0.017296     0.005520
# std           0.106984     0.048224     0.113820     0.130381     0.074097
# min           0.000000     0.000000     0.000000     0.000000     0.000000
# 25%           0.861353     0.000000     0.000000     0.000000     0.000000
# 50%           0.906288     0.000000     0.000000     0.000000     0.000000
# 75%           0.961555     0.000000     0.000000     0.000000     0.000000
# max           1.000000     1.000000     1.000000     1.000000     1.000000
#
#        ...   country_NO   country_NZ   country_PL   country_PT   country_US  \
# count  ...  8152.000000  8152.000000  8152.000000  8152.000000  8152.000000
# mean   ...     0.041953     0.047718     0.040972     0.046246     0.065260
# std    ...     0.200494     0.213183     0.198236     0.210031     0.246999
# min    ...     0.000000     0.000000     0.000000     0.000000     0.000000
# 25%    ...     0.000000     0.000000     0.000000     0.000000     0.000000
# 50%    ...     0.000000     0.000000     0.000000     0.000000     0.000000
# 75%    ...     0.000000     0.000000     0.000000     0.000000     0.000000
# max    ...     1.000000     1.000000     1.000000     1.000000     1.000000
#
#        review_difficulty_Challenging  review_difficulty_Easy  \
# count                    8152.000000             8152.000000
# mean                        0.093106                0.354882
# std                         0.290599                0.478507
# min                         0.000000                0.000000
# 25%                         0.000000                0.000000
# 50%                         0.000000                0.000000
# 75%                         0.000000                1.000000
# max                         1.000000                1.000000
#
#        review_difficulty_Very_Challenging  review_difficulty_Very_Easy  \
# count                         8152.000000                  8152.000000
# mean                             0.002085                     0.081575
# std                              0.045621                     0.273733
# min                              0.000000                     0.000000
# 25%                              0.000000                     0.000000
# 50%                              0.000000                     0.000000
# 75%                              0.000000                     0.000000
# max                              1.000000                     1.000000
#
#        review_difficulty_unknown
# count                8152.000000
# mean                    0.162659
# std                     0.369077
# min                     0.000000
# 25%                     0.000000
# 50%                     0.000000
# 75%                     0.000000
# max                     1.000000
#
# [8 rows x 99 columns]

# %%
std = train.describe().list_price['std']
median = train.describe().list_price['50%']
print(std)
print(median)
# Out:
# 96.16600644823507
# 36.5878

# %%
max_value = median + std*2
max_value
# Out:
# 228.91981289647015

# %%
train_new = train[train['list_price']<max_value]
train_new.head()
# Out:
#       piece_count  list_price  num_reviews  play_star_rating  star_rating  \
# 7465     0.549419     12.1878     0.000000          0.000000     0.781585
# 4139     0.364926     32.9278     0.117376          1.000000     1.000000
# 2363     0.604625     15.5922     0.329516          0.906288     0.805755
# 151      0.518024      9.9900     0.000000          0.861353     0.781585
# 2451     0.497603     10.1322     0.117376          1.000000     1.000000
#
#       val_star_rating  ages_10_14  ages_10_16  ages_10_21  ages_11_16  ...  \
# 7465         0.682606           0           0           0           0  ...
# 4139         1.000000           0           0           0           0  ...
# 2363         0.906288           0           0           0           0  ...
# 151          0.861353           0           0           0           0  ...
# 2451         1.000000           0           0           0           0  ...
#
#       country_NO  country_NZ  country_PL  country_PT  country_US  \
# 7465           0           0           0           0           0
# 4139           0           0           0           0           0
# 2363           0           0           0           0           0
# 151            0           0           0           0           1
# 2451           0           0           0           0           0
#
#       review_difficulty_Challenging  review_difficulty_Easy  \
# 7465                              0                       0
# 4139                              0                       0
# 2363                              0                       1
# 151                               0                       1
# 2451                              0                       1
#
#       review_difficulty_Very_Challenging  review_difficulty_Very_Easy  \
# 7465                                   0                            1
# 4139                                   0                            1
# 2363                                   0                            0
# 151                                    0                            0
# 2451                                   0                            0
#
#       review_difficulty_unknown
# 7465                          0
# 4139                          0
# 2363                          0
# 151                           0
# 2451                          0
#
# [5 rows x 99 columns]

# %%
#remove outliers from test set 
test_new = test[test['list_price']<max_value]

# %%
model4 = ols(formula=formula, data=train_new).fit()
model4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             list_price   R-squared:                       0.783
# Model:                            OLS   Adj. R-squared:                  0.781
# Method:                 Least Squares   F-statistic:                     497.6
# Date:                Thu, 12 Nov 2020   Prob (F-statistic):               0.00
# Time:                        18:29:02   Log-Likelihood:                -29979.
# No. Observations:                6677   AIC:                         6.006e+04
# Df Residuals:                    6628   BIC:                         6.039e+04
# Df Model:                          48
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                           68.0716      3.430     19.845      0.000      61.348      74.796
# piece_count                                        175.7006      2.791     62.947      0.000     170.229     181.172
# num_reviews                                         30.2579      1.689     17.914      0.000      26.947      33.569
# play_star_rating                                    44.1857      3.279     13.474      0.000      37.757      50.614
# val_star_rating                                    -71.6484      2.845    -25.185      0.000     -77.225     -66.072
# ages_10_14                                        -119.5245      5.558    -21.504      0.000    -130.421    -108.628
# ages_10_16                                         -68.1587      3.242    -21.025      0.000     -74.514     -61.804
# ages_11_16                                         -27.2936      4.761     -5.733      0.000     -36.626     -17.961
# ages_12plus                                         41.4124      4.720      8.774      0.000      32.160      50.664
# ages_12_16                                         -16.5081      6.184     -2.669      0.008     -28.631      -4.385
# ages_16plus                                         95.0679      7.564     12.568      0.000      80.239     109.897
# ages_1half_3                                       -21.9795      3.091     -7.111      0.000     -28.039     -15.920
# ages_1half_5                                       -22.5814      2.512     -8.990      0.000     -27.506     -17.657
# ages_2_5                                           -10.6045      1.632     -6.497      0.000     -13.804      -7.405
# ages_4_7                                           -36.4350      2.098    -17.371      0.000     -40.547     -32.323
# ages_4_99                                          -46.6354      5.709     -8.168      0.000     -57.827     -35.443
# ages_5plus                                         -48.1472      2.287    -21.049      0.000     -52.631     -43.663
# ages_5_12                                         -113.9159      2.390    -47.659      0.000    -118.602    -109.230
# ages_5_8                                           -33.5531      3.598     -9.326      0.000     -40.606     -26.500
# ages_6plus                                        -116.9467      3.849    -30.383      0.000    -124.492    -109.401
# ages_6_12                                         -112.0225      2.384    -46.993      0.000    -116.695    -107.349
# ages_6_14                                         -108.3422      3.485    -31.087      0.000    -115.174    -101.510
# ages_7plus                                       -7.902e-14   7.32e-15    -10.788      0.000   -9.34e-14   -6.47e-14
# ages_7_12                                         -111.8351      2.511    -44.543      0.000    -116.757    -106.913
# ages_7_14                                         -113.2219      2.375    -47.668      0.000    -117.878    -108.566
# ages_8plus                                         -65.8374      3.852    -17.094      0.000     -73.388     -58.287
# ages_8_12                                          -98.8016      2.743    -36.014      0.000    -104.180     -93.424
# ages_8_14                                         -103.0363      2.474    -41.651      0.000    -107.886     -98.187
# ages_9_12                                         -117.7052      4.410    -26.690      0.000    -126.350    -109.060
# ages_9_14                                          -72.7141      2.706    -26.867      0.000     -78.020     -67.408
# ages_9_16                                          -83.9966      3.430    -24.487      0.000     -90.721     -77.272
# theme_name_Architecture                           -154.2630      5.480    -28.149      0.000    -165.006    -143.520
# theme_name_BOOST                                   107.0014      5.946     17.995      0.000      95.345     118.658
# theme_name_Blues_Helicopter_Pursuit              -3.044e-14   4.63e-15     -6.573      0.000   -3.95e-14   -2.14e-14
# theme_name_BrickHeadz                             -114.1146      2.654    -43.005      0.000    -119.316    -108.913
# theme_name_Classic                                 -62.9197      5.767    -10.910      0.000     -74.225     -51.615
# theme_name_Creator_Expert                         -153.6656      7.694    -19.971      0.000    -168.749    -138.582
# theme_name_DUPLO                                   -55.1654      1.976    -27.919      0.000     -59.039     -51.292
# theme_name_Ghostbusters                            -11.1044     15.345     -0.724      0.469     -41.185      18.976
# theme_name_Ideas                                  -111.5645      3.709    -30.080      0.000    -118.835    -104.294
# theme_name_Indoraptor_Rampage_at_Lockwood_Estate    86.1837      6.001     14.362      0.000      74.421      97.947
# theme_name_Juniors                                 -69.9882      2.306    -30.347      0.000     -74.509     -65.467
# theme_name_Minecraft                               -24.8812      3.004     -8.282      0.000     -30.770     -18.992
# theme_name_Minifigures                             -48.1472      2.287    -21.049      0.000     -52.631     -43.663
# theme_name_NINJAGO                                 -15.6804      2.195     -7.144      0.000     -19.983     -11.378
# theme_name_SERIOUS_PLAY                             -8.8541      6.163     -1.437      0.151     -20.936       3.227
# country_CA                                         -13.0753      1.053    -12.415      0.000     -15.140     -11.011
# country_DN                                          -8.6251      1.279     -6.744      0.000     -11.132      -6.118
# country_FI                                           6.8779      1.308      5.259      0.000       4.314       9.442
# country_NO                                           7.2458      1.359      5.331      0.000       4.581       9.910
# country_US                                         -11.5751      1.062    -10.900      0.000     -13.657      -9.493
# review_difficulty_Challenging                       15.8790      1.257     12.634      0.000      13.415      18.343
# review_difficulty_Easy                             -10.6989      0.681    -15.706      0.000     -12.034      -9.364
# review_difficulty_Very_Easy                          2.2045      1.198      1.840      0.066      -0.145       4.554
# ==============================================================================
# Omnibus:                     1703.511   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6242.797
# Skew:                           1.242   Prob(JB):                         0.00
# Kurtosis:                       7.034   Cond. No.                     1.20e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.57e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
#Check homoskedacticity again

y_hat_new = train_new['list_price'] - model4.predict(train_new[x_cols])

plt.scatter(model4.predict(train_new[x_cols]), y_hat_new)
plt.plot(model4.predict(train_new[x_cols]), [0 for i in range(len(train_new))])

# %%
#Check normality again

fig = sm.qqplot(model4.resid, line='45', fit=True)

# %%
# Try and fix normality by taking log of continuous variables

#We ran the following code below and then chose to return to the start of our notebook to take the logs at the beginning:
#Code below is shown to explain our process

# continuous = ['play_star_rating', 'val_star_rating', 'piece_count']
# train_log = train.copy()
# test_log = test.copy()

# for col in continuous:
#     train_log[col] = train_log[col].map(lambda x: np.log(x))
#     test_log[col] = test_log[col].map(lambda x: np.log(x))

# %%
# model5 = ols(formula=formula, data=train_log).fit()
# model5.summary()
